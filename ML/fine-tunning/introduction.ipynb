# %%
import torchvision as tv
import torch

# %%
msa_model = tv.models.mnasnet1_0

# %%
model = msa_model(pretrained=True)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MNASNet1_0_Weights.IMAGENET1K_V1`. You can also use `weights=MNASNet1_0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for param in model.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[[[-1.1771e-07,  7.2651e-07, -1.9708e-07],
#           [-4.3148e-07,  1.7870e-06,  6.4579e-07],
#           [ 3.3944e-07,  7.3515e-07, -3.4845e-07]],
#
#          [[ 3.3135e-07,  6.7277e-07,  8.9448e-07],
#           [ 1.1472e-06,  2.4788e-06,  2.8642e-06],
#           [ 1.5862e-07,  1.6717e-06,  1.3821e-06]],
#
#          [[-1.2082e-06,  1.2603e-07, -2.5768e-07],
#           [ 2.6793e-07,  1.4329e-06,  9.7745e-07],
#           [-1.2257e-06,  5.1851e-07,  4.5977e-07]]],
#
#
#         [[[ 1.4349e-01,  3.6604e-02,  5.9193e-02],
#           [ 8.6124e-01,  1.2839e-01,  6.1031e-02],
#           [ 1.0622e-01,  4.6938e-02,  8.6977e-02]],
#
#          [[-3.6256e-02, -1.2241e-01, -7.5226e-02],
#           [ 1.3939e+00,  3.2397e-01, -6.3442e-02],
#           [ 1.6056e-01, -5.1599e-02, -3.8106e-02]],
#
#          [[-1.2484e-01,  2.6309e-02, -2.6893e-02],
#           [ 7.7547e-01,  6.1376e-02, -2.9259e-01],
#           [-2.1677e-01, -7.3701e-02, -3.9597e-02]]],
#
# ...

# %%
weights = tv.models.MNASNet1_0_Weights.DEFAULT
data_shape = weights.transforms()

# %%
size = data_shape.crop_size[0]
channels = len(data_shape.mean)
N_samples = 10

# %%
ts = torch.zeros(size=(N_samples, channels, size, size))
